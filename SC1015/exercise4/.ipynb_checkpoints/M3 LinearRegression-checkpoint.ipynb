# %% [markdown]
# # Linear Regression in Python
#
# Dataset from Kaggle : **"Pokemon with stats"** by *Alberto Barradas*
# Source: https://www.kaggle.com/abcsds/pokemon (requires login)
#
# ---
#
# ### Essential Libraries
#
# Let us begin by importing the essential Python Libraries.
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ---
#
# ### Import the Dataset
#
# The dataset is in CSV format; hence we use the `read_csv` function from Pandas.
# Immediately after importing, take a quick look at the data using the `head` function.

# %%
pkmndata = pd.read_csv('pokemonData.csv')
pkmndata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Description of the dataset, as available on Kaggle, is as follows.
# Learn more : https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon
#
# > **\#** : ID for each Pokemon (runs from 1 to 721)
# > **Name** : Name of each Pokemon
# > **Type 1** : Each Pokemon has a basic Type, this determines weakness/resistance to attacks
# > **Type 2** : Some Pokemons are dual type and have a Type 2 value (set to nan otherwise)
# > **Total** : Sum of all stats of a Pokemon, a general guide to how strong a Pokemon is
# > **HP** : Hit Points, defines how much damage a Pokemon can withstand before fainting
# > **Attack** : The base modifier for normal attacks by the Pokemon (e.g., scratch, punch etc.)
# > **Defense** : The base damage resistance of the Pokemon against normal attacks
# > **SP Atk** : Special Attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# > **SP Def** : Special Defense, the base damage resistance against special attacks
# > **Speed** : Determines which Pokemon attacks first each round
# > **Generation** : Each Pokemon belongs to a certain Generation
# > **Legendary** : Legendary Pokemons are powerful, rare, and hard to catch
#
# ---
#
# Check the vital statistics of the dataset using the `type` and `shape` attributes.

# %%
print("Data type : ", type(pkmndata))
print("Data dims : ", pkmndata.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (800, 13)

# %% [markdown]
# Check the variables (and their types) in the dataset using the `dtypes` attribute.

# %%
print(pkmndata.dtypes)
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ---
#
# ## Uni-Variate Linear Regression
#
# We will start by setting up a Uni-Variate Linear Regression problem.
#
# Response Variable : **Total**
# Predictor Feature : **HP**
#
# > Regression Model : Total = $a$ $\times$ HP + $b$
#
# Extract the variables and the associated data as a Pandas `DataFrame`.

# %%
total = pd.DataFrame(pkmndata['Total'])  # Response
hp = pd.DataFrame(pkmndata['HP'])        # Predictor

# %% [markdown]
# Set up the regression problem with Train and Test datasets.
# Train Set with 600 samples and Test Set with 200 samples.

# %%
# Train Set : 600 samples, no random sampling, just take first 600
hp_train = pd.DataFrame(hp[:600])
total_train = pd.DataFrame(total[:600])

# Test Set : 200 samples no random sampling, just take last 200
hp_test = pd.DataFrame(hp[-200:])
total_test = pd.DataFrame(total[-200:])

# Check the sample sizes
print("Train Set :", hp_train.shape, total_train.shape)
print("Test Set  :", hp_test.shape, total_test.shape)
# Out:
# Train Set : (600, 1) (600, 1)
# Test Set  : (200, 1) (200, 1)

# %% [markdown]
# #### Basic Exploration
#
# Perform basic statistical exploration and visualization on the Train Set.

# %%
# Summary Statistics for HP Train
hp_train.describe()
# Out:
#                HP
# count  600.000000
# mean    69.026667
# std     26.611267
# min      1.000000
# 25%     50.000000
# 50%     65.000000
# 75%     80.000000
# max    255.000000

# %%
# Summary Statistics for Total Train
total_train.describe()
# Out:
#             Total
# count  600.000000
# mean   432.715000
# std    122.365283
# min    180.000000
# 25%    325.000000
# 50%    440.000000
# 75%    515.000000
# max    780.000000

# %%
# Set up matplotlib figure with three subplots
f, axes = plt.subplots(2, 3, figsize=(24, 12))

# Plot the basic uni-variate figures for HP Train
sb.boxplot(data = hp_train, orient = "h", ax = axes[0,0])
sb.histplot(data = hp_train, ax = axes[0,1])
sb.violinplot(data = hp_train, orient = "h", ax = axes[0,2])

# Plot the basic uni-variate figures for Total Train
sb.boxplot(data = total_train, orient = "h", ax = axes[1,0],color='g')
sb.histplot(data = total_train, ax = axes[1,1],color='g',alpha=1)
sb.violinplot(data = total_train, orient = "h", ax = axes[1,2],color='g')
# Out:
# <AxesSubplot:>

# %%
# Create a joint dataframe by concatenating the two variables
trainDF = pd.concat([hp_train, total_train], axis = 1).reindex(hp_train.index)

# Jointplot of Total Train against HP Train
sb.jointplot(data = trainDF, x = "HP", y = "Total", height = 12)

# %%
# Calculate the correlation between the two columns/variables
sb.heatmap(trainDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Linear Regression using Scikit-Learn
#
# Scikit-Learn (`sklearn`) will be our de-facto Machine Learning library in Python.
# Import the `LinearRegression` model from `sklearn.linear_model`.

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

# %% [markdown]
# Train the Linear Regression model `linreg` using the Train Set.
# Use `hp_train` as *Predictor* and `total_train` as *Response*.

# %%
# Train the Linear Regression model
linreg.fit(hp_train, total_train)
# Out:
# LinearRegression()

# %% [markdown]
# You have *trained* the model to fit the following formula.
#
# >  Regression Problem : Total = $a$ $\times$ HP + $b$
#
# Check Intercept ($a$) and Coefficient ($b$) of the regression line.

# %%
# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [245.18583183]
# Coefficients 	: a =  [[2.71676407]]

# %% [markdown]
# Plot the regression line based on the coefficients-intercept form.

# %%
# Formula for the Regression line
regline_x = hp_train
regline_y = linreg.intercept_ + linreg.coef_ * hp_train 
print(type(regline_y)) #doing any form of addition and multiplication on a dataframe gives back a dataframe
print(type(linreg.intercept_))

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(hp_train, total_train)
plt.plot(regline_x, regline_y,'r-', linewidth = 3) #this is basically Y=mX+C, the list of X coorindates is the same as the original, the list of Y coordinates is bascially mX+C where X is that corresponding X coordinate, and m and C comes from the model
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %% [markdown]
# Plot the regression line by prediction using the model.

# %%
# Predict Total values corresponding to HP Train
total_train_pred = linreg.predict(hp_train)
print(total_train_pred.shape)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(hp_train, total_train)
plt.scatter(hp_train, regline_y, color = "r")
plt.show()
#linreg.predict does the same thing as Ax+b, where A and B are the values linreg.coef and linreg.intercept respectively, producing a dataframe
f = plt.figure(figsize=(16, 8))
plt.scatter(hp_train, total_train)
plt.scatter(hp_train, total_train_pred, color = "r")
plt.show()
# Out:
# (600, 1)

# %% [markdown]
# #### Goodness of Fit of the Model
#
# Check how good the predictions are on the Train Set.
# Metrics : Explained Variance and Mean Squared Error.

# %%
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(hp_train, total_train))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    #takes dataframes and converts them into np arrays for numerical operations
    return np.mean(np.square(np.array(actual) - np.array(predicted)))


mse = mean_sq_err(total_train, total_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
print("This is the best possible error(optimized) since we have already run it through linear regression, it cannot be any better for a linear model for this particular set of test data")
# Out:
# Explained Variance (R^2) 	: 0.3483472365042858
# Mean Squared Error (MSE) 	: 9741.105636728045
# Root Mean Squared Error (RMSE) 	: 98.69703965534146
# This is the best possible error(optimized) since we have already run it through linear regression, it cannot be any better for a linear model for this particular set of test data

# %% [markdown]
# Test the Linear Regression model `linreg` using the Test Set.

# %%
# Predict Total values corresponding to HP Test
total_test_pred = linreg.predict(hp_test)

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(hp_test, total_test, color = "green")
plt.scatter(hp_test, total_test_pred, color = "red")
plt.show()

# %% [markdown]
# Check how good the predictions are on the Test Set.
# Metrics : Explained Variance and Mean Squared Error.

# %%
# Explained Variance (R^2)
#look at the R^2 formula, a and b come from the model which is the linreg object, we are simply passing in any test data, by giving the predictor(xaxis) and the response(yaxis) and seeing how the model we have trained, fits the test data
#we are not passing in our predicted mX+C values, the m and the C alr inside the linreg object
print("Explained Variance (R^2) \t:", linreg.score(hp_test, total_test))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(total_test, total_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.4914319675664691
# Mean Squared Error (MSE) 	: 6397.401764721523
# Root Mean Squared Error (RMSE) 	: 79.98375938102386

# %% [markdown]
# ## TEST DATA ERROR IS LOWER THAN TRAINING DATA ERROR!!

# %% [markdown]
# ## This is theoretically wrong and mathematically impossible, for a perfect linear model

# %% [markdown]
# ## It is also counter-intuitive and does not make sense, since the model is supposed to be optimized to the training data and should give lowest error possible

# %% [markdown]
# #### Regression with Random Train-Test Split
#
# Split the Train and Test sets randomly, and perform Linear Regression.
#
# **Take note that linear regression does not produce the same linear model every time, ie different models with different coefficients and intercepts will be generated each time**

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #helps split data evenly and randomly
from sklearn.metrics import mean_squared_error #built in function to help perform Goodness-Of-Fit test

# Recall the Total-HP Dataset
total = pd.DataFrame(pkmndata['Total'])   # Response
hp = pd.DataFrame(pkmndata['HP'])         # Predictor

# Split the Dataset into Train and Test
#tuple unpacking
#X is HP the predictor
#Y is TOTAL the response
#this function splits data randomly and this is where all the randomness comes from
X_train, X_test, y_train, y_test = train_test_split(hp, total, test_size = 0.25)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (600, 1)
# (200, 1)
# (600, 1)
# (200, 1)

# %% [markdown]
# ### we are only predicting Y, the response variable. THERE IS NO X to predict!!! since its the independent one

# %%
# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        
# train the linear regression model, the A and B CHANGES EVERY TIME not because there is multiple "Best fits", mathematically there is only one minimised cost linear model for each set of data
#it is because the data we run the model on changes everytime due the spliting of data, which introduced random

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Total values corresponding to HP
y_train_pred = linreg.predict(X_train) # passing in "X" and get "mX+C" which is Y
y_test_pred = linreg.predict(X_test) # passing in "X" and get "mX+C" which is Y

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
print("The perfect case for plotting predicted response and the real reponse, ie TOTAL is on the line y=x, it means the predicted values are EXCACTLY the real values, means the prediction is perfect. Any deviation from the line shows how bad the prediction is compared to the perfect prediction")
# Out:
# Intercept of Regression 	: b =  [236.01909031]
# Coefficients of Regression 	: a =  [[2.83427097]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.37443192475850995
# Mean Squared Error (MSE) 	: 9006.837187082225
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.4023261876655543
# Mean Squared Error (MSE) 	: 8505.829988515983
# The perfect case for plotting predicted response and the real reponse, ie TOTAL is on the line y=x, it means the predicted values are EXCACTLY the real values, means the prediction is perfect. Any deviation from the line shows how bad the prediction is compared to the perfect prediction

# %%
# Predict Total values corresponding to X Test data
y_test_pred = linreg.predict(X_test)

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# ---
#
# ## Multi-Variate Linear Regression
#
# We will start by setting up a Multi-Variate Linear Regression problem.
#
# Response Variable : **Total**
# Predictor Feature : **HP, Attack, Defense**
#
# > Regression Model : Total = $a_1$ $\times$ HP + $a_2$ $\times$ Attack + $a_3$ $\times$ Defense + $b$
#
# Extract the variables and the associated data as a Pandas `DataFrame`.

# %%
# Extract Response and Predictors
y = pd.DataFrame(pkmndata["Total"]) #small letter y cos its a vector
X = pd.DataFrame(pkmndata[["HP", "Attack", "Defense"]]) #capital letter cos its a matrix

# %% [markdown]
# Set up the regression problem with Train and Test datasets.

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (600, 1) (600, 3)
# Test Set  : (200, 1) (200, 3)

# %% [markdown]
# #### Basic Exploration
#
# Perform basic statistical exploration and visualization on the Train Set.

# %%
# Summary Statistics for Response
y_train.describe()
# Out:
#             Total
# count  600.000000
# mean   441.530000
# std    121.785941
# min    180.000000
# 25%    330.000000
# 50%    455.500000
# 75%    520.000000
# max    780.000000

# %%
# Summary Statistics for Predictors
X_train.describe()
# Out:
#                HP      Attack     Defense
# count  600.000000  600.000000  600.000000
# mean    69.966667   80.401667   74.238333
# std     26.228396   33.576967   30.897777
# min      1.000000    5.000000    5.000000
# 25%     50.000000   55.000000   50.000000
# 50%     67.000000   76.000000   70.000000
# 75%     80.250000  100.000000   90.000000
# max    255.000000  190.000000  230.000000

# %% [markdown]
# ## Response

# %%
# Draw the distribution of Response
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = y_train, orient = "h", ax = axes[0])
sb.histplot(data = y_train, ax = axes[1])
sb.violinplot(data = y_train, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Predictors

# %%
# Draw the distributions of all Predictors
f, axes = plt.subplots(3, 3, figsize=(18, 12))

count = 0
for var in X_train:
    sb.boxplot(data = X_train[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = X_train[var], ax = axes[count,1])
    sb.violinplot(data = X_train[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
# Correlation between Response and the Predictors
trainDF = pd.concat([y_train, X_train], axis = 1).reindex(y_train.index)

f = plt.figure(figsize=(12, 8))
sb.heatmap(trainDF.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
# Relationship between Response and the Predictors
sb.pairplot(data = trainDF)
print("We are more concerned about the relationships between the response(TOTAL) and each of the predictors, whether they have any correlation to the reponse, that determines if they belong in a linear regession model")
# Out:
# We are more concerned about the relationships between the response(TOTAL) and each of the predictors, whether they have any correlation to the reponse, that determines if they belong in a linear regession model

# %% [markdown]
# ## Linear Regression using Scikit-Learn

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [98.35943497]
# Coefficients of Regression 	: a =  [[1.6427243  1.67615936 1.2590344 ]]
#   Predictors  Coefficients
# 0         HP      1.642724
# 1     Attack      1.676159
# 2    Defense      1.259034

# %% [markdown]
# Response Variable : **Total**
# Predictor Feature : **HP, Attack, Defense**
#
# > Regression Model : Total = $a_1$ $\times$ HP + $a_2$ $\times$ Attack + $a_3$ $\times$ Defense + $b$

# %%
# Predict the Total values from Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Model

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7680730653134888
# Mean Squared Error (MSE) 	: 3434.164332772615
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6629909973701189
# Mean Squared Error (MSE) 	: 4238.066014020543

# %% [markdown]
# ## Notice it is impossible to visualize and plot the linear model for a multi-variable, since its now multi-dimensional, the Y_pred is a vector in R^n where n is the number of predictor variables
# **Each of the coefficients are the weights to each of the predictor variables**

# %% [markdown]
# ---
#
# ## Multi-Variate Linear Regression
#
# Let us set up another Multi-Variate Linear Regression problem.
#
# Response Variable : **Total**
# Predictor Feature : **HP, Attack, Defense, Sp. Atk, Sp. Def, Speed**
#
# > Regression Model : Total = $a_1$ $\times$ HP + $a_2$ $\times$ Attack + $a_3$ $\times$ Defense + $a_4$ $\times$ Sp. Atk + $a_5$ $\times$ Sp. Def + $a_6$ $\times$ Speed + $b$

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Extract Response and Predictors
y = pd.DataFrame(pkmndata["Total"])
X = pd.DataFrame(pkmndata[["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
print(pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [-5.68434189e-14]
# Coefficients of Regression 	: a =  [[1. 1. 1. 1. 1. 1.]]
#
#   Predictors  Coefficients
# 0         HP           1.0
# 1     Attack           1.0
# 2    Defense           1.0
# 3    Sp. Atk           1.0
# 4    Sp. Def           1.0
# 5      Speed           1.0
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 1.0
# Mean Squared Error (MSE) 	: 1.1489517167199769e-26
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 1.0
# Mean Squared Error (MSE) 	: 1.1801864013085678e-26

# %% [markdown]
# # Corollary:
# **we now get a perfect prediction, the predicted values and the true response values now exactly lie on the line y=x, R^2 is 1, the best you can ever get**
# but this is not a surprise, because total is completely and directly related to all the different stats and predictor variables added together, but something like this does not happen in real life. e.g. predicting the tip of a restaurant based on no. of vistors, revenue for the day....etc. There is no such thing as a formula for calculating the tip, thus we need regression to understand if its connected to certain other variables or not
#
# *if you already have a completely deterministic way of calculating the response variable based on predictor variables, then linear regression is not even needed at all!*

# %% [markdown]
# Each of the variables also have different weights in affecting the response variable, and that is determined by its correlation to the response variable

# %% [markdown]
# ---
#
# ## Prediction using a Regression Model
#
# Once we have trained a Multi-Variate Regression Model, we may use it to predict **Total** for any particular Pokemon.
#
# > Regression Model : Total = $a_1$ $\times$ HP + $a_2$ $\times$ Attack + $a_3$ $\times$ Defense + $b$

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Extract Response and Predictors
predictors = ["HP", "Attack", "Defense"]

y = pd.DataFrame(pkmndata["Total"])
X = pd.DataFrame(pkmndata[predictors])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
print(pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [96.88785908]
# Coefficients of Regression 	: a =  [[1.67414629 1.57618849 1.35652236]]
#
#   Predictors  Coefficients
# 0         HP      1.674146
# 1     Attack      1.576188
# 2    Defense      1.356522
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7303930337001221
# Mean Squared Error (MSE) 	: 3717.775870420832
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7893522166634126
# Mean Squared Error (MSE) 	: 3396.1779394326195

# %% [markdown]
# #### Prediction of Total
#
# Let's predict the value of **Total** for a few specific Pokemons -- *Charizard*, *Snorlax* and *Vivillon* -- using the Regression Model derived above.

# %%
# Extract Pokemons for Prediction
pkmndata_pred = pkmndata[pkmndata["Name"].isin(["Charizard", "Snorlax", "Vivillon"])]
pkmndata_pred
# Out:
#        #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 6      6  Charizard    Fire  Flying    534   78      84       78      109
# 155  143    Snorlax  Normal     NaN    540  160     110       65       65
# 734  666   Vivillon     Bug  Flying    411   80      52       50       90
#
#      Sp. Def  Speed  Generation  Legendary
# 6         85    100           1      False
# 155      110     30           1      False
# 734       50     89           6      False

# %%
# Extract Predictors for Prediction
X_pred = pd.DataFrame(pkmndata_pred[predictors])

# Predict Response corresponding to Predictors
y_pred = linreg.predict(X_pred)
y_pred
# Out:
# array([[465.67984659],
#        [626.30595204],
#        [380.60748141]])

# %%
# Summarize the Actuals, Predictions and Errors
y_pred = pd.DataFrame(y_pred, columns = ["PredTotal"], index = pkmndata_pred.index)
pkmndata_acc = pd.concat([pkmndata_pred[["Name", "Total"]], y_pred], axis = 1)

y_errs = 100 * abs(pkmndata_acc["Total"] - pkmndata_acc["PredTotal"]) / pkmndata_acc["Total"]
y_errs = pd.DataFrame(y_errs, columns = ["Error"], index = pkmndata_pred.index)
pkmndata_acc = pd.concat([pkmndata_acc, y_errs], axis = 1)

pkmndata_acc
# Out:
#           Name  Total   PredTotal      Error
# 6    Charizard    534  465.679847  12.794036
# 155    Snorlax    540  626.305952  15.982584
# 734   Vivillon    411  380.607481   7.394773

# %% [markdown]
# #### Prediction Interval
#
# The confidence on Prediction depends on the Distribution and Deviation of the Errors in Prediction.
# We obtain the Mean Squared Error on the Train Set while fitting/training the Linear Regression Model.
#
# The Standard Error of Prediction may be estimated as $StdE = \sqrt{\frac{n}{n-2} MSE}$ from the Train Set.

# %%
MSE_train = mean_squared_error(y_train, y_train_pred)
StdE_pred = np.sqrt(len(y_train) * MSE_train/(len(y_train) - 2))

print("Mean Squared Error (MSE) \t:", MSE_train.round(2))
print("Pred Standard Error (SE) \t:", StdE_pred.round(2))
#think of standard error as the standard deviation of all the errors in MSE
#assume the errors have a mean of 0, remember they "all" pass through the line
# Out:
# Mean Squared Error (MSE) 	: 3717.78
# Pred Standard Error (SE) 	: 61.08

# %% [markdown]
# In Prediction, we assume a Gaussian (Normal) Distribution for Predictions Errors.
# The `95%` Prediction Interval for any data point is given by $Prediction \pm 1.96 \times StdE$
# The `99%` Prediction Interval for any data point is given by $Prediction \pm 2.58 \times StdE$

# %%
y_95l = pd.DataFrame(pkmndata_acc["PredTotal"] - 1.96*StdE_pred).rename(columns = {"PredTotal" : "95 Lower"})
y_95u = pd.DataFrame(pkmndata_acc["PredTotal"] + 1.96*StdE_pred).rename(columns = {"PredTotal" : "95 Upper"})
y_99l = pd.DataFrame(pkmndata_acc["PredTotal"] - 2.58*StdE_pred).rename(columns = {"PredTotal" : "99 Lower"})
y_99u = pd.DataFrame(pkmndata_acc["PredTotal"] + 2.58*StdE_pred).rename(columns = {"PredTotal" : "99 Upper"})

pkmndata_int = pd.concat([pkmndata_acc, y_95l, y_95u, y_99l, y_99u], axis = 1)
pkmndata_int
# Out:
#           Name  Total   PredTotal      Error    95 Lower    95 Upper  \
# 6    Charizard    534  465.679847  12.794036  345.971976  585.387718
# 155    Snorlax    540  626.305952  15.982584  506.598081  746.013823
# 734   Vivillon    411  380.607481   7.394773  260.899610  500.315352
#
#        99 Lower    99 Upper
# 6    308.105200  623.254493
# 155  468.731306  783.880598
# 734  223.032835  538.182128

# %% [markdown]
# *prediction interval tells us: is it abnormal to have such a error rate? of 12%, 15%, 7% respectively*

# %% [markdown]
# ### Explanation:
# Lets take **charizard** as example. Assume we do not know the total score for charizard. We only know the predicted total, from all his other variables. That gives us 465.68. We can say that we predict **charizard's** total score to be 465.68 including some error of around 13%. However, from the standard error distribution, we have the 95% confidnence that **charizard's** total score will be between 345 and 585.
#
# *There is a 95% chance that the actual value of **charizard's** total score is between 345 and 585.*

# %% [markdown]
# ## Takeaway
# We can never be 100% certain about something, only with a certain probability. And that is okay.
# Although we are not 100% sure, we know how sure we are.
#
# *Its never about being 100% sure, its about knowing how sure you are*

# %% [markdown]
# Sometimes the range is too big, so we would also like to narrow the range down. The more variables you have, the lower your standard error, the narrower your range.
