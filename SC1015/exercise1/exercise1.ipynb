# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot

# %%
sb.set() # set the default Seaborn style for graphics
pkmndata = pd.read_csv('pokemonData.csv')
pkmndata.head()
print(type(pkmndata['HP']))
hp = pd.DataFrame(pkmndata['HP'])# DataFrame not only takes in a python dict, but also a series and converts it back to a dataframes
print("Data type : ", type(hp))
print("Data dims : ", hp.size)
hp.head(10)
#f=plt.figure(figsize=(24, 10))
#g=plt.figure(figsize=(2, 4))
sb.boxplot(data = hp, orient = "h")
# plt.show()
# plt.close()

#plt.figure(figsize=(24, 10))
sb.kdeplot(data = hp)
print("Data dims : ", hp.size)
"""Explanation: it runs sequentially, but the plots do not display right away, even if they are executed before othe print statements, it gets
shown only after everything. Evidence: can display 2 plots using 2 different figures in the same cell, means that figures do not overwrite each other.
However, despite there being no overwrite, any figure created on top will essentially be useless and not referenced by any plot functions below.
Evidence: creating 2 figures in a row, the calling 2 plots in a row, both plots will appear only only the latest figure, and the earlier figure is not even shown at all.
Explanation: each plot function when called, looks above for the nearest figure available, and dumps all its data on it. It does not care whether the figure has alr been used by another plot function
Evidence: can have 2 plots worth of infomation on the same figure. This also means that figures do not get used up by a plot function, the same figure created and be plotted on over and over again, but it only displays all its shit at the end,
after all printables in the script has been printed.

Question: what happens when no figure created? is auto 1 figure?
"""
# Out:
# <class 'pandas.core.series.Series'>
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  800
# Data dims :  800
# ...

# %% [markdown]
# # part(a)

# %% [markdown]
# trains=pd.read_csv("train.csv")
# trains.head()

# %%
trains.shape
# Out:
# (1460, 81)

# %%
trains.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
trains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ### info()
# displays all the information about the dataframe, including all its data types, coloumn names, and how many entries each coloumn has

# %%
trains.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ### describe()
# shows all the agregated statistics of each coloumn

# %% [markdown]
# # part(b)

# %%
medals= pd.read_html("https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table")

medals[2]
# Out:
#                    Rank                   NOC  Gold  Silver  Bronze  Total
# 0                     1         United States    46      37      38    121
# 1                     2         Great Britain    27      23      17     67
# 2                     3                 China    26      18      26     70
# 3                     4                Russia    19      17      20     56
# 4                     5               Germany    17      10      15     42
# ..                  ...                   ...   ...     ...     ...    ...
# 82                   78               Nigeria     0       0       1      1
# 83                   78              Portugal     0       0       1      1
# 84                   78   Trinidad and Tobago     0       0       1      1
# 85                   78  United Arab Emirates     0       0       1      1
# 86  Totals (86 entries)   Totals (86 entries)   306     307     359    972
#
# [87 rows x 6 columns]

# %%
len(medals)
# Out:
# 7

# %%
medals2016= pd.DataFrame(medals[2])
medals2016
# Out:
#                    Rank                   NOC  Gold  Silver  Bronze  Total
# 0                     1         United States    46      37      38    121
# 1                     2         Great Britain    27      23      17     67
# 2                     3                 China    26      18      26     70
# 3                     4                Russia    19      17      20     56
# 4                     5               Germany    17      10      15     42
# ..                  ...                   ...   ...     ...     ...    ...
# 82                   78               Nigeria     0       0       1      1
# 83                   78              Portugal     0       0       1      1
# 84                   78   Trinidad and Tobago     0       0       1      1
# 85                   78  United Arab Emirates     0       0       1      1
# 86  Totals (86 entries)   Totals (86 entries)   306     307     359    972
#
# [87 rows x 6 columns]

# %%
medals2016top20=pd.DataFrame(medals2016.head(20))
medals2016top20
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1  United States    46      37      38    121
# 1     2  Great Britain    27      23      17     67
# 2     3          China    26      18      26     70
# 3     4         Russia    19      17      20     56
# 4     5        Germany    17      10      15     42
# 5     6          Japan    12       8      21     41
# 6     7         France    10      18      14     42
# 7     8    South Korea     9       3       9     21
# 8     9          Italy     8      12       8     28
# 9    10      Australia     8      11      10     29
# 10   11    Netherlands     8       7       4     19
# 11   12        Hungary     8       3       4     15
# 12   13        Brazil*     7       6       6     19
# 13   14          Spain     7       4       6     17
# 14   15          Kenya     6       6       1     13
# 15   16        Jamaica     6       3       2     11
# 16   17        Croatia     5       3       2     10
# ...

# %% [markdown]
# # bonus(A)

# %%
income=pd.read_html("https://archive.ics.uci.edu/ml/datasets/Census+Income")
# Out:
# [                                                   0  \
#  0  Center for Machine Learning and Intelligent Sy...
#
#                                                     1
#  0  About Citation Policy Donate a Data Set Contac...  ,
#                                                     0
#  0  Census Income Data Set \tDownload: Data Folder...,
#                                                     0   1
#  0  Census Income Data Set \tDownload: Data Folder... NaN,
#                              0                     1                      2  \
#  0   Data Set Characteristics:          Multivariate   Number of Instances:
#  1  Attribute Characteristics:  Categorical, Integer  Number of Attributes:
#  2           Associated Tasks:        Classification        Missing Values?
#
#         3                    4           5
#  0  48842                Area:      Social
#  1     14         Date Donated  1996-05-01
#  2    Yes  Number of Web Hits:      741194  ,
# ...

# %%
len(income)
# Out:
# 5

# %%
print(income[0].shape)
print(income[0].info())
print(income[0].describe())
income[0]
# Out:
# (1, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      object
#  1   1       1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# None
#                                                         0  \
# count                                                   1
# unique                                                  1
# top     Center for Machine Learning and Intelligent Sy...
# freq                                                    1
#
#                                                         1
# count                                                   1
# unique                                                  1
# top     About Citation Policy Donate a Data Set Contac...
# freq                                                    1
#                                                    0  \
# ...

# %% [markdown]
# # bonus(b)

# %%
tally={}
for i in range(2000,2017,4):
    url="https://en.wikipedia.org/wiki/{}_Summer_Olympics_medal_table".format(i)
    data=pd.read_html(url)[2].head(20)
    tally[i]=data
for item in tally:
    print(item)
    print(tally[item])
# Out:
# 2000
#    Rank         Nation  Gold  Silver  Bronze  Total
# 0     1  United States    37      24      32     93
# 1     2         Russia    32      28      29     89
# 2     3          China    28      16      14     58
# 3     4     Australia*    16      25      17     58
# 4     5        Germany    13      17      26     56
# 5     6         France    13      14      11     38
# 6     7          Italy    13       8      13     34
# 7     8    Netherlands    12       9       4     25
# 8     9           Cuba    11      11       7     29
# 9    10  Great Britain    11      10       7     28
# 10   11        Romania    11       6       9     26
# 11   12    South Korea     8      10      10     28
# 12   13        Hungary     8       6       3     17
# 13   14         Poland     6       5       3     14
# 14   15          Japan     5       8       5     18
# 15   16       Bulgaria     5       6       2     13
# 16   17         Greece     4       6       3     13
# ...
